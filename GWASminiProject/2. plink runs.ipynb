# %%
# %%bash
#
# plink --vcf ../../plink-182/data/filtered.vcf.gz --make-bed --out ../../plink-182/data/filtered
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../plink-182/data/filtered.log.
# Options in effect:
#   --make-bed
#   --out ../plink-182/data/filtered
#   --vcf ../plink-182/data/filtered.vcf.gz
#
# 385411 MB RAM detected; reserving 192705 MB for main workspace.
# --vcf: ../plink-182/data/filtered-temporary.bed +
# ../plink-182/data/filtered-temporary.bim +
# ../plink-182/data/filtered-temporary.fam written.
# 170073 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to ../plink-182/data/filtered.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
#  done.
# 170073 variants and 2504 people pass filters and QC.
# Note: No phenotypes present.
# ...

# %%
# %%bash
#
# #Plink results when we don't account for pop strat
#
# DATADIR=../../plink-182/data
# #DATADIR=~/ps3/
# PREFIX=${DATADIR}/filtered # use for plink --bfile
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# TYPE=Nocontrol
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results # use for plink --out
#
# # YOUR CODE HERE
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --allow-no-sex --out ${OUTPREFIX1}
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --allow-no-sex --out ${OUTPREFIX2}
#
# # Change to more useable output format
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
# Out:
# PLINK v1.90b6.9 64-bit (4 Mar 2019)            www.cog-genomics.org/plink/1.9/
# (C) 2005-2019 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to ../Project/Runs/Noenvironmenteffect/Nocontrol/results.log.
# Options in effect:
#   --allow-no-sex
#   --bfile ../plink-182/data/filtered
#   --linear
#   --out ../Project/Runs/Noenvironmenteffect/Nocontrol/results
#   --pheno ../Project/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1.phen
#
# 385411 MB RAM detected; reserving 192705 MB for main workspace.
# 170073 variants loaded from .bim file.
# 2504 people (0 males, 0 females, 2504 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to
# ../Project/Runs/Noenvironmenteffect/Nocontrol/results.nosex .
# 2504 phenotype values present after --pheno.
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 2504 founders and 0 nonfounders present.
#  done.
# 170073 variants and 2504 people pass filters and QC.
# ...

# %%
# %%bash
#
# ## Plink results if we use PCA
#
# TYPE=PCA_HPS_whiten_False
# DATADIR=../../plink-182/data
# PREFIX=${DATADIR}/filtered # use for plink --bfile
# USERPREFIX1='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# USERPREFIX2='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}
#
#
#
# # YOUR CODE HERE
# ### NUMVARS1
# NUMVARS=1
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1 --allow-no-sex --out ${OUTPREFIX1}
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1 --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### NUMVARS2
# NUMVARS=2
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# #### NUMVARS3
# #NUMVARS=3
# #OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
# #
# #cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# #cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
# #
# #
# #### NUMVARS4
# #NUMVARS=4
# #OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
# #
# #cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# #cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
# #
# #
# #### NUMVARS5
# #NUMVARS=5
# #OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
# #
# #cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# #cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
# #
# #
# Out:
# Process is terminated.

# %%
# %%bash
#
# ## Plink results if we use PCoA
#
# TYPE=PCoA_HPS_metric_manhattan
# DATADIR=../../plink-182/data
# PREFIX=${DATADIR}/filtered # use for plink --bfile
# USERPREFIX1='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# USERPREFIX2='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}
#
# mkdir ../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}
# mkdir ../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}
#
# # YOUR CODE HERE
# ### NUMVARS1
# NUMVARS=1
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1 --allow-no-sex --out ${OUTPREFIX1}
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1 --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### NUMVARS2
# NUMVARS=2
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### NUMVARS3
# #NUMVARS=3
# #OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
#
# #cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# #cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### NUMVARS4
# #NUMVARS=4
# #OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
#
# #cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# #cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### NUMVARS5
# #NUMVARS=5
# #OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
# #OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${NUMVARS} # use for plink --out
#
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX1}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX1}
# #plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX2}.phen --covar ${COVARFILE}.cov --covar-number 1-${NUMVARS} --allow-no-sex --out ${OUTPREFIX2}
#
# #cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# #cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
# Out:
# Process is terminated.

# %%
# %%bash
#
# ###### Using TSNE braycurtis
#
# TYPE=t-SNE_HPS_metric_braycurtis_perplexity
# DATADIR=../../plink-182/data
# PREFIX=${DATADIR}/filtered # use for plink --bfile
#
#
# #mkdir ../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}
# #mkdir ../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}
#
# # YOUR CODE HERE
# ### PERPLEX2
# PERPLEX=2
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX3
# PERPLEX=3
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX10
# PERPLEX=10
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX30
# PERPLEX=30
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX100
# PERPLEX=100
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab

# %%
# %%bash
#
# ###### Using TSNE manhattan
#
# TYPE=t-SNE_HPS_metric_manhattan_perplexity
# DATADIR=../../plink-182/data
# PREFIX=${DATADIR}/filtered # use for plink --bfile
#
# #mkdir ../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}
# #mkdir ../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}
#
# # YOUR CODE HERE
# ### PERPLEX2
# PERPLEX=2
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX3
# PERPLEX=3
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX10
# PERPLEX=10
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX30
# PERPLEX=30
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
# ### PERPLEX100
# PERPLEX=100
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PERPLEX}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PERPLEX} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab

# %%
# %%bash
#
# ######## Using UMAP
#
# TYPE=UMAP_HPS
# DATADIR=../../plink-182/data
# PREFIX=${DATADIR}/filtered # use for plink --bfile
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
#
# #mkdir ../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}
# #mkdir ../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}
#
#
#
# # YOUR CODE HERE
# ### PARAMS UMAP_HPS_metric_braycurtis_min_dist_0.1_n_neighbors_10
# PARAMS=metric_braycurtis_min_dist_0.1_n_neighbors_10
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PARAMS}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PARAMS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PARAMS} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### PARAMS UMAP_HPS_metric_manhattan_min_dist_0.1_n_neighbors_10
# PARAMS=metric_manhattan_min_dist_0.1_n_neighbors_10
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PARAMS}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PARAMS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PARAMS} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
#
#
# ### PARAMS UMAP_HPS_metric_canberra_min_dist_0.1_n_neighbors_50
# PARAMS=metric_canberra_min_dist_0.1_n_neighbors_50
# COVARFILE=../../plink-182/cov_dr_outputs/${TYPE}_${PARAMS}
# OUTPREFIX1=../GWASminiProject/Runs/Noenvironmenteffect/${TYPE}/results_${PARAMS} # use for plink --out
# OUTPREFIX2=../GWASminiProject/Runs/Yesenvironmenteffect/${TYPE}/results_${PARAMS} # use for plink --out
#
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Noenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov --allow-no-sex --out ${OUTPREFIX1}
# USERPREFIX='../GWASminiProject/SimulatedPhenotypes/Yesenvironmenteffect/pheno_sim1'
# plink --bfile ${PREFIX} --linear --pheno ${USERPREFIX}.phen --covar ${COVARFILE}.cov  --allow-no-sex --out ${OUTPREFIX2}
#
# cat ${OUTPREFIX1}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX1}.assoc.linear.tab
# cat ${OUTPREFIX2}.assoc.linear | sed -r 's/^\s+//g' | sed -r 's/\s+/\t/g' > ${OUTPREFIX2}.assoc.linear.tab
